# %%
import pandas as pd

# %%
# Subject: very high + high

base_dir = '/Users/imdohyeon/Library/CloudStorage/GoogleDrive-dhlim1598@gmail.com/공유 드라이브/4N_PKNU/Project/EEG-LLM/Dataset/subj(high+inter)/'
data1 = pd.read_csv(base_dir + 'laf_eeg_data_9ch_360000.csv')
data2 = pd.read_csv(base_dir + 'laf_eeg_data2_9ch_240000.csv')

# %%
# 데이터 합치기
data = pd.concat([data1, data2], axis=0)

# %%
data
# Out:
#              FC3       FCz       FC4        C3        Cz        C4       CP3  \
# 0       0.004885  0.021394 -0.004997  0.000477  0.018715 -0.030185 -0.011860
# 1       0.000437  0.017261 -0.002674  0.003289  0.015006 -0.031561 -0.010945
# 2       0.004613  0.014660 -0.000274  0.000667  0.010949 -0.031562 -0.008879
# 3       0.016540  0.013472  0.004274 -0.003721  0.007394 -0.029907 -0.006108
# 4       0.023611  0.014114  0.004756 -0.004507  0.003148 -0.023453 -0.000821
# ...          ...       ...       ...       ...       ...       ...       ...
# 239995  0.043431  0.024130  0.029494 -0.009207 -0.027949 -0.049328 -0.040003
# 239996  0.034528  0.030303  0.035609 -0.009888 -0.026360 -0.049572 -0.023452
# 239997  0.026627  0.035436  0.041257 -0.012342 -0.026241 -0.051329  0.000513
# 239998  0.017483  0.037924  0.047005 -0.014076 -0.030238 -0.049147  0.025322
# 239999  0.003724  0.035337  0.062659 -0.012908 -0.033988 -0.042228  0.040724
#
#              CPz       CP4  label
# ...

# %%
data.to_csv(base_dir + 'laf_eeg_data_9ch_600000.csv', index=False)

# %%
# Subject: very high + high + fair

base_dir = '/Users/imdohyeon/Library/CloudStorage/GoogleDrive-dhlim1598@gmail.com/공유 드라이브/4N_PKNU/Project/EEG-LLM/Dataset/subj(high+inter+low)/'
data1 = pd.read_csv(base_dir + 'laf_eeg_data_9ch_360000.csv')
data2 = pd.read_csv(base_dir + 'laf_eeg_data2_9ch_240000.csv')
data3 = pd.read_csv(base_dir + 'laf_eeg_data3_9ch_240000.csv')

# %%
data = pd.concat([data1, data2, data3], axis=0)

# %%
data
# Out:
#              FC3       FCz       FC4        C3        Cz        C4       CP3  \
# 0       0.004885  0.021394 -0.004997  0.000477  0.018715 -0.030185 -0.011860
# 1       0.000437  0.017261 -0.002674  0.003289  0.015006 -0.031561 -0.010945
# 2       0.004613  0.014660 -0.000274  0.000667  0.010949 -0.031562 -0.008879
# 3       0.016540  0.013472  0.004274 -0.003721  0.007394 -0.029907 -0.006108
# 4       0.023611  0.014114  0.004756 -0.004507  0.003148 -0.023453 -0.000821
# ...          ...       ...       ...       ...       ...       ...       ...
# 239995 -0.029551  0.023615 -0.018839  0.004575  0.023919 -0.014516 -0.018566
# 239996 -0.028830  0.023304 -0.018926  0.005345  0.024892 -0.013452 -0.020600
# 239997 -0.029110  0.022831 -0.019267  0.004893  0.027360 -0.012168 -0.020882
# 239998 -0.030903  0.025107 -0.021943  0.004109  0.029337 -0.010909 -0.020409
# 239999 -0.034116  0.028762 -0.025682  0.004595  0.029957 -0.009851 -0.018917
#
#              CPz       CP4  label
# ...

# %%
data.to_csv(base_dir + 'laf_eeg_data_9ch_840000.csv', index=False)
