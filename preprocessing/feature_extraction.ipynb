# %%
import pandas as pd
from feature_extraction import load_eeg_data, compute_band_power, extract_features
from fisher_ratio import calculate_fisher_ratio, sort_fisher_ratios

# %%
# EEG 데이터 파일 경로
file_path = '/Users/imdohyeon/Documents/PythonWorkspace/EEG-GPT/Dataset/final_eeg_data.csv'
data = load_eeg_data(file_path, sfreq=250)
# Out:
# Creating RawArray with float64 data, n_channels=60, n_times=180000
#     Range : 0 ... 179999 =      0.000 ...   719.996 secs
# Ready.

# %%
tmpdata = pd.read_csv(file_path)
tmpdata
# Out:
#             #  1       #  2       #  3       #  4       #  5       #  6  \
# 0      -3.348520  -0.250720  -2.482654  -1.851242  -2.175465  -0.987844
# 1      -3.615057  -0.941355  -3.589869  -2.098366  -4.178424  -3.049562
# 2      -3.428481  -1.134885  -4.175011  -2.005247  -3.297852  -3.190218
# 3      -2.926504  -0.781978  -3.947261  -1.704401  -1.107828  -2.090882
# 4      -3.219694  -1.427076  -4.115446  -2.574706  -0.473634  -1.879898
# ...          ...        ...        ...        ...        ...        ...
# 179995 -2.628872  -2.861472  -1.449020  -3.878372  -2.700158   0.067074
# 179996 -0.145641   0.777642   1.890144   0.627156   1.588638   3.435410
# 179997  2.759607   4.716537   5.166239   5.207896   4.193853   6.670494
# 179998  6.735442   9.653437   9.591595  10.350931   7.738954  11.223300
# 179999  9.538517  13.102817  12.485771  13.054964  11.658183  15.032111
#
#              #  7       #  8       #  9       # 10  ...      # 51      # 52  \
# ...

# %%
features = extract_features(data)
# Out:
# Effective window size : 8.192 (s)
# Effective window size : 8.192 (s)
# Effective window size : 8.192 (s)

# %%
features
# Out:
#                                0         1         2         3         4   \
# Alpha:Delta Power Ratio  0.484914  0.604590  0.601096  0.597981  0.595677
# Theta:Alpha Power Ratio  1.174177  1.107693  1.119239  1.077712  1.076180
# Delta:Theta Power Ratio  1.756312  1.493205  1.486391  1.551707  1.559927
#
#                                5         6         7         8         9   \
# Alpha:Delta Power Ratio  0.663840  0.693811  0.663719  0.573425  0.639081
# Theta:Alpha Power Ratio  1.052681  1.025263  1.009918  0.994623  0.957330
# Delta:Theta Power Ratio  1.431000  1.405800  1.491865  1.753334  1.634491
#
#                          ...        50        51        52        53  \
# Alpha:Delta Power Ratio  ...  2.407085  2.313319  2.598394  3.053406
# Theta:Alpha Power Ratio  ...  0.252745  0.284454  0.227054  0.188466
# Delta:Theta Power Ratio  ...  1.643715  1.519679  1.694984  1.737730
#
#                                54        55        56        57        58  \
# ...

# %%
dataforfisher = pd.read_csv('/Users/imdohyeon/Documents/PythonWorkspace/EEG-GPT/Dataset/final_eeg_data_labeled.csv')

# %%
# 데이터 컬럼명 설정 (가정: 마지막 열이 라벨)
dataforfisher.columns = [f'channel_{i+1}' for i in range(dataforfisher.shape[1] - 1)] + ['label']

# Fisher Ratio 계산
fisher_ratios = calculate_fisher_ratio(dataforfisher)
fisher_ratios
# Out:
# {'channel_1': 1.3081683349719188e-05,
#  'channel_2': 1.0733911807771094e-05,
#  'channel_3': 4.104424661713149e-06,
#  'channel_4': 9.236863068691616e-06,
#  'channel_5': 7.712007495824555e-06,
#  'channel_6': 6.451964154612709e-06,
#  'channel_7': 4.3018241698994905e-06,
#  'channel_8': 5.85251129630099e-06,
#  'channel_9': 9.673718310602155e-06,
#  'channel_10': 7.6206241256634365e-06,
#  'channel_11': 5.778978409879509e-06,
#  'channel_12': 4.862150606262487e-06,
#  'channel_13': 4.151077950938163e-06,
#  'channel_14': 6.1024638624285e-06,
#  'channel_15': 9.636592875798957e-06,
#  'channel_16': 1.4093969578415763e-05,
#  'channel_17': 3.3282021722611237e-06,
#  'channel_18': 3.003466299048417e-06,
#  'channel_19': 3.3788676665487814e-06,
#  'channel_20': 3.112338383905174e-06,
#  'channel_21': 6.297818966227027e-06,
#  'channel_22': 8.448762429602226e-06,
#  'channel_23': 1.1840176943453228e-05,
#  'channel_24': 1.4572619473429119e-05,
#  'channel_25': 1.6036526517687282e-05,
# ...

# %%
# Fisher Ratios를 오름차순으로 정렬
sorted_fisher_ratios = sort_fisher_ratios(fisher_ratios)
sorted_fisher_ratios
# Out:
# {'channel_39': 2.942033571900988e-06,
#  'channel_18': 3.003466299048417e-06,
#  'channel_20': 3.112338383905174e-06,
#  'channel_17': 3.3282021722611237e-06,
#  'channel_19': 3.3788676665487814e-06,
#  'channel_28': 3.5252866819509997e-06,
#  'channel_29': 3.6483950746300093e-06,
#  'channel_26': 4.020261756382267e-06,
#  'channel_3': 4.104424661713149e-06,
#  'channel_13': 4.151077950938163e-06,
#  'channel_7': 4.3018241698994905e-06,
#  'channel_12': 4.862150606262487e-06,
#  'channel_37': 5.102312942238607e-06,
#  'channel_27': 5.1111264428081195e-06,
#  'channel_58': 5.417252215265211e-06,
#  'channel_11': 5.778978409879509e-06,
#  'channel_8': 5.85251129630099e-06,
#  'channel_14': 6.1024638624285e-06,
#  'channel_21': 6.297818966227027e-06,
#  'channel_30': 6.396211384924109e-06,
#  'channel_6': 6.451964154612709e-06,
#  'channel_40': 6.509411676109847e-06,
#  'channel_59': 6.547917999965534e-06,
#  'channel_38': 6.662531496243411e-06,
#  'channel_46': 6.851043042532105e-06,
# ...
