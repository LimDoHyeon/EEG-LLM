# %%
import csv_to_json as ctoj
import feature_extraction as fe
import pandas as pd
import numpy as np
import json

data, label = fe.load_eeg_data('/Users/imdohyeon/Documents/PythonWorkspace/EEG-GPT/Dataset/final_eeg_data_labeled.csv')
window_size = 1000
# selected_columns = data.columns # test
selected_columns = [1, 4, 5, 7, 10]
labels = label

# ctoj.csv_to_json(data, window_size, selected_columns, labels)
ctoj.csv_to_json(data, window_size, selected_columns, labels)
# Out:
# Creating RawArray with float64 data, n_channels=5, n_times=1000
#     Range : 0 ... 999 =      0.000 ...     3.996 secs
# Ready.
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Creating RawArray with float64 data, n_channels=5, n_times=1000
#     Range : 0 ... 999 =      0.000 ...     3.996 secs
# Ready.
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Creating RawArray with float64 data, n_channels=5, n_times=1000
#     Range : 0 ... 999 =      0.000 ...     3.996 secs
# Ready.
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Creating RawArray with float64 data, n_channels=5, n_times=1000
#     Range : 0 ... 999 =      0.000 ...     3.996 secs
# Ready.
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# ...
