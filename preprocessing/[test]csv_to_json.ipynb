# %%
import csv_to_json as ctoj
import feature_extraction as fe
import pandas as pd
import numpy as np
import json

# %%
data = fe.load_eeg_data('/Users/imdohyeon/Documents/PythonWorkspace/EEG-GPT/Dataset/final_eeg_data_labeled.csv')
data
# Out:
#             #  1       #  2       #  3       #  4       #  5       #  6  \
# 0      -3.348520  -0.250720  -2.482654  -1.851242  -2.175465  -0.987844
# 1      -3.615057  -0.941355  -3.589869  -2.098366  -4.178424  -3.049562
# 2      -3.428481  -1.134885  -4.175011  -2.005247  -3.297852  -3.190218
# 3      -2.926504  -0.781978  -3.947261  -1.704401  -1.107828  -2.090882
# 4      -3.219694  -1.427076  -4.115446  -2.574706  -0.473634  -1.879898
# ...          ...        ...        ...        ...        ...        ...
# 179995 -2.628872  -2.861472  -1.449020  -3.878372  -2.700158   0.067074
# 179996 -0.145641   0.777642   1.890144   0.627156   1.588638   3.435410
# 179997  2.759607   4.716537   5.166239   5.207896   4.193853   6.670494
# 179998  6.735442   9.653437   9.591595  10.350931   7.738954  11.223300
# 179999  9.538517  13.102817  12.485771  13.054964  11.658183  15.032111
#
#              #  7       #  8       #  9       # 10  ...      # 52       # 53  \
# ...

# %%
window_size = 1000
selected_columns = data.columns # test
labels = data.iloc[:, -1]

ctoj.csv_to_json(data, window_size, selected_columns, labels)
# Out:
# Creating RawArray with float64 data, n_channels=61, n_times=1000
#     Range : 0 ... 999 =      0.000 ...     3.996 secs
# Ready.
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Creating RawArray with float64 data, n_channels=61, n_times=1000
#     Range : 0 ... 999 =      0.000 ...     3.996 secs
# Ready.
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Creating RawArray with float64 data, n_channels=61, n_times=1000
#     Range : 0 ... 999 =      0.000 ...     3.996 secs
# Ready.
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Creating RawArray with float64 data, n_channels=61, n_times=1000
#     Range : 0 ... 999 =      0.000 ...     3.996 secs
# Ready.
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# Effective window size : 1.024 (s)
# ...

# %%
labels

# %% [markdown]
# ## Former test

# %%
# Simulated example data
data = {
    'E1': np.random.randn(2500),
    'E9': np.random.randn(2500),
    'E13': np.random.randn(2500)
}
df = pd.DataFrame(data)
window_size = 500
selected_columns = ['E1', 'E9', 'E13']
labels = ['left', 'right', 'top', 'bottom', 'left'] * (len(df) // window_size)

json_result = ctoj.csv_to_json(df, window_size, selected_columns, labels)

# Displaying a sample output with 5 prompts
sample_output = json.dumps(json_result[:5], indent=4)
print(sample_output)
